# %% [markdown]
# $$w \text{ ahora es un vector  }\vec{w} $$
# $$x \text{ ahora es un vector  }\vec{x} $$
# $$\text{b sigue siendo un escalar } b$$
#
# Ahora se puede escribir $f(w,b)$ como:
#
# $$ f(w,b) = \vec{w} \cdot{} \vec{x} + b$$
